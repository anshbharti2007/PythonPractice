# %% [markdown]
# # Problem 1
# Hello, World!

# %%
print("Hello, World!")

# %%
nums = [2,5,1,3,4,7]
n = 3
lst1 = []
lst2 = []
# Out:
# [[2, 5, 1]]
# []

# %%
#not doing exercism 
#practicing while doing projects now
