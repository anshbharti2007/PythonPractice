# %%
# problem 1
fruits = ["apple", 1,  "banana", "cherry"]
fruits.append("Goldenfish")
fruits.insert(5, "Time")
fruits.remove("Goldenfish")
fruits.pop()
fruits.reverse()
fruits.sort()
print(fruits)
# Out:
# ['apple', 'banana', 'cherry']
