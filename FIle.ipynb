# %%
file = open("Good.txt", "w")
file.write(
    "First time use this method to make a file and write\n"
    "lets go" 
           )
# Out:
# 59

# %%
file = open("Good.txt", "r")
print(file)
# Out:
# <_io.TextIOWrapper name='Good.txt' mode='r' encoding='UTF-8'>
