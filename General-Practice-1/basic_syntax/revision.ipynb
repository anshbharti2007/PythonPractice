# %%
#List 
nums = [3, 1, 4, 1, 5, 9]
nums.append(10)
nums.pop()
nums.sort()
nums[0]
len(nums)
sum(nums)
nums[-1]
nums[::-1]
nums[1:4]
# Out:
# Running cells with '.venv1\ (3.14.4) (Python 3.14.4)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/home/shinon/Documents/GitHub/.venv1//bin/python -m pip install ipykernel -U --force-reinstall'
